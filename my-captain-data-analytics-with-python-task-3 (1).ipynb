# %% [markdown]
# <h2> My Captain Data Analytics with Python task 3: Note down the marks you have scored in all the cycle tests in your previous year of college and visualize the data in a bar plot.</h2>

# %%
#Importing the required modules and libraries of Python
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the Dataset i.e. the 1_Year_Results.csv file
df = pd.read_csv('1_Year_Results.csv')
df
# Out:
#    Paper Code                                   Paper Name  Sem  \
# 0       58651                  Engineering Mathematics - 1    1
# 1    58651 TW        Engineering Mathematics - 1 Term Work    1
# 2       58652                      Engineering Physics -1     1
# 3      FEL101           Engineering Physics -1 (Practical)    1
# 4       58655                    Engineering Chemistry - 1    1
# 5      FEL102        Engineering Chemistry - 1 (Practical)    1
# 6       58653                        Engineering Mechanics    1
# 7      FEL103           Engineering Mechanics (Practical)     1
# 8       58654                 Basic Electrical Engineering    1
# 9      FEL104     Basic Electrical Engineering (Practical)    1
# 10     FEL105      Basic Workshop practice - 1 (Practical)    1
# 11     FEC201                 Engineering Mathematics - 2     2
# 12  FEC201 TW        Engineering Mathematics - 2 Term Work    2
# 13     FEC202                       Engineering Physics -2    2
# 14     FEL201                  Engineering Physics -2 (TW)    2
# 15     FEC203                    Engineering Chemistry - 2    2
# 16     FEL202               Engineering Chemistry - 2 (TW)    2
# 17     FEC204                         Engineering Graphics    2
# 18     FEL203                    Engineering Graphics (TW)    2
# 19     FEC205                              C - Programming    2
# 20     FEL204                         C - Programming (TW)    2
# 21     FEC206       Professional Communication & Ethics -1    2
# 22     FEL205  Professional Communication & Ethics -1 (TW)    2
# 23     FEL206      Basic Workshop practice - 2 (Practical)    2
#
#     Marks Received   Maximum Marks
# 0                59            100
# 1                22             25
# 2                41             75
# 3                20             25
# 4                58             75
# 5                23             25
# 6                62            100
# 7                41             50
# 8                61            100
# 9                38             50
# 10               42             50
# 11               63            100
# 12               23             25
# 13               61             75
# 14               22             25
# 15               56             75
# 16               22             25
# 17               56             75
# 18               66             75
# 19               63             75
# 20               47             50
# 21               40             50
# 22               22             25
# 23               45             50

# %%
#Creating 2 different datasets of Sem 1 and Sem 2 respectively
Sem_1 = df[df['Sem'] == 1]
Sem_2 = df[df['Sem'] == 2]
Sem_1
# Out:
#    Paper Code                                Paper Name  Sem  Marks Received   \
# 0       58651               Engineering Mathematics - 1    1               59
# 1    58651 TW     Engineering Mathematics - 1 Term Work    1               22
# 2       58652                   Engineering Physics -1     1               41
# 3      FEL101        Engineering Physics -1 (Practical)    1               20
# 4       58655                 Engineering Chemistry - 1    1               58
# 5      FEL102     Engineering Chemistry - 1 (Practical)    1               23
# 6       58653                     Engineering Mechanics    1               62
# 7      FEL103        Engineering Mechanics (Practical)     1               41
# 8       58654              Basic Electrical Engineering    1               61
# 9      FEL104  Basic Electrical Engineering (Practical)    1               38
# 10     FEL105   Basic Workshop practice - 1 (Practical)    1               42
#
#     Maximum Marks
# 0             100
# 1              25
# 2              75
# 3              25
# 4              75
# 5              25
# 6             100
# 7              50
# 8             100
# 9              50
# 10             50

# %%
Sem_2
# Out:
#    Paper Code                                   Paper Name  Sem  \
# 11     FEC201                 Engineering Mathematics - 2     2
# 12  FEC201 TW        Engineering Mathematics - 2 Term Work    2
# 13     FEC202                       Engineering Physics -2    2
# 14     FEL201                  Engineering Physics -2 (TW)    2
# 15     FEC203                    Engineering Chemistry - 2    2
# 16     FEL202               Engineering Chemistry - 2 (TW)    2
# 17     FEC204                         Engineering Graphics    2
# 18     FEL203                    Engineering Graphics (TW)    2
# 19     FEC205                              C - Programming    2
# 20     FEL204                         C - Programming (TW)    2
# 21     FEC206       Professional Communication & Ethics -1    2
# 22     FEL205  Professional Communication & Ethics -1 (TW)    2
# 23     FEL206      Basic Workshop practice - 2 (Practical)    2
#
#     Marks Received   Maximum Marks
# 11               63            100
# 12               23             25
# 13               61             75
# 14               22             25
# 15               56             75
# 16               22             25
# 17               56             75
# 18               66             75
# 19               63             75
# 20               47             50
# 21               40             50
# 22               22             25
# 23               45             50

# %%
#Calculating Percentage of marks scored for each subject in Sem_1 and storing them as list in Sem_1_percent
Sem_1_percent = []
for x in range(0,1):
    Sem_1_percent.append((Sem_1['Marks Received '] / Sem_1['Maximum Marks'])*100)
Sem_1_percent_data = pd.DataFrame(Sem_1_percent)
Sem_1_percent_data.transpose()
# Out:
#             0
# 0   59.000000
# 1   88.000000
# 2   54.666667
# 3   80.000000
# 4   77.333333
# 5   92.000000
# 6   62.000000
# 7   82.000000
# 8   61.000000
# 9   76.000000
# 10  84.000000

# %%
Sem_1['Percentage'] = Sem_1_percent_data.transpose()
Sem_1
# Out:
#    Paper Code                                Paper Name  Sem  Marks Received   \
# 0       58651               Engineering Mathematics - 1    1               59
# 1    58651 TW     Engineering Mathematics - 1 Term Work    1               22
# 2       58652                   Engineering Physics -1     1               41
# 3      FEL101        Engineering Physics -1 (Practical)    1               20
# 4       58655                 Engineering Chemistry - 1    1               58
# 5      FEL102     Engineering Chemistry - 1 (Practical)    1               23
# 6       58653                     Engineering Mechanics    1               62
# 7      FEL103        Engineering Mechanics (Practical)     1               41
# 8       58654              Basic Electrical Engineering    1               61
# 9      FEL104  Basic Electrical Engineering (Practical)    1               38
# 10     FEL105   Basic Workshop practice - 1 (Practical)    1               42
#
#     Maximum Marks  Percentage
# 0             100   59.000000
# 1              25   88.000000
# 2              75   54.666667
# 3              25   80.000000
# 4              75   77.333333
# 5              25   92.000000
# 6             100   62.000000
# 7              50   82.000000
# 8             100   61.000000
# 9              50   76.000000
# 10             50   84.000000

# %%
#Similarly add percentage column to Sem_2 Dataset
Sem_2_percent = []
for x in range(0,1):
    Sem_2_percent.append((Sem_2['Marks Received '] / Sem_2['Maximum Marks'])*100)
Sem_2_percent_data = pd.DataFrame(Sem_2_percent)
Sem_2_percent_data.transpose()
# Out:
#             0
# 11  63.000000
# 12  92.000000
# 13  81.333333
# 14  88.000000
# 15  74.666667
# 16  88.000000
# 17  74.666667
# 18  88.000000
# 19  84.000000
# 20  94.000000
# 21  80.000000
# 22  88.000000
# 23  90.000000

# %%
Sem_2['Percentage'] = Sem_2_percent_data.transpose()
Sem_2
# Out:
#    Paper Code                                   Paper Name  Sem  \
# 11     FEC201                 Engineering Mathematics - 2     2
# 12  FEC201 TW        Engineering Mathematics - 2 Term Work    2
# 13     FEC202                       Engineering Physics -2    2
# 14     FEL201                  Engineering Physics -2 (TW)    2
# 15     FEC203                    Engineering Chemistry - 2    2
# 16     FEL202               Engineering Chemistry - 2 (TW)    2
# 17     FEC204                         Engineering Graphics    2
# 18     FEL203                    Engineering Graphics (TW)    2
# 19     FEC205                              C - Programming    2
# 20     FEL204                         C - Programming (TW)    2
# 21     FEC206       Professional Communication & Ethics -1    2
# 22     FEL205  Professional Communication & Ethics -1 (TW)    2
# 23     FEL206      Basic Workshop practice - 2 (Practical)    2
#
#     Marks Received   Maximum Marks  Percentage
# 11               63            100   63.000000
# 12               23             25   92.000000
# 13               61             75   81.333333
# 14               22             25   88.000000
# 15               56             75   74.666667
# 16               22             25   88.000000
# 17               56             75   74.666667
# 18               66             75   88.000000
# 19               63             75   84.000000
# 20               47             50   94.000000
# 21               40             50   80.000000
# 22               22             25   88.000000
# 23               45             50   90.000000

# %% [markdown]
# <h3> Analysis of Sem 1 result using matplotlib </h3>

# %%
#Bar Graph plotting of Sem_1 dataset
Sem_1.plot(x='Paper Name', y = ['Marks Received ','Maximum Marks'], kind = 'barh', figsize = (10,5), grid = True)
# Out:
# <AxesSubplot:ylabel='Paper Name'>

# %%
#Bar Graph plotting of Sem_1 percentage
Sem_1.plot(x='Paper Name', y = 'Percentage', kind = 'bar', figsize = (10,5), grid = True)
# Out:
# <AxesSubplot:xlabel='Paper Name'>

# %%
#Pie Graph plotting of Sem_1 percentage
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
ax.pie(Sem_1['Percentage'], labels = Sem_1['Paper Name'],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# <h2>Analysis of Sem 2 result using matplotlib</h2>

# %%
#Bar Graph plotting of Sem_2 dataset
Sem_2.plot(x='Paper Name', y = ['Marks Received ','Maximum Marks'], kind = 'barh', figsize = (10,5), grid = True)
# Out:
# <AxesSubplot:ylabel='Paper Name'>

# %%
#Bar Graph plotting of Sem_2 percentage
Sem_2.plot(x='Paper Name', y = 'Percentage', kind = 'bar', figsize = (10,5), grid = True)
# Out:
# <AxesSubplot:xlabel='Paper Name'>

# %%
#Pie Graph plotting of Sem_2 percentage
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
ax.pie(Sem_2['Percentage'], labels = Sem_2['Paper Name'],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# <h2> Comparision of Marks scored in Sem 1 and Sem 2 </h2>

# %%
Total_marks_in_sem_1 = Sem_1['Maximum Marks'].sum()
Total_marks_scored_in_sem_1 = Sem_1['Marks Received '].sum()
percentage_in_sem_1 = ((Total_marks_scored_in_sem_1/Total_marks_in_sem_1) * 100 )
Total_marks_in_sem_1, Total_marks_scored_in_sem_1, percentage_in_sem_1
# Out:
# (675, 467, 69.18518518518518)

# %%
Total_marks_in_sem_2 = Sem_2['Maximum Marks'].sum()
Total_marks_scored_in_sem_2 = Sem_2['Marks Received '].sum()
percentage_in_sem_2 = ((Total_marks_scored_in_sem_2/Total_marks_in_sem_2) * 100 )
Total_marks_in_sem_2, Total_marks_scored_in_sem_2, percentage_in_sem_2
# Out:
# (725, 586, 80.82758620689656)

# %%
Marks = { 'Sem 1' : [Total_marks_in_sem_1, Total_marks_scored_in_sem_1, percentage_in_sem_1],      
          'Sem 2' : [Total_marks_in_sem_2, Total_marks_scored_in_sem_2, percentage_in_sem_2]
}
Sem_1_2_marks = pd.DataFrame(Marks)
Sem_1_2_marks
# Out:
#         Sem 1       Sem 2
# 0  675.000000  725.000000
# 1  467.000000  586.000000
# 2   69.185185   80.827586

# %%
sns.heatmap(Sem_1_2_marks, annot=True, linecolor='yellow',linewidths=3)
# Out:
# <AxesSubplot:>
